# %%
import json
# get development_data.json and ns_to_function_map.json
with open('production_data.json', encoding='utf-8') as f:
    development_data = json.load(f)
with open('ns_to_function_map.json') as f:
    ns_to_function_map = json.load(f)
save_to_file = "production_conversations.json"

# %%
from collections import defaultdict
from datetime import datetime

# Group the data by conversationId
grouped_data_temp = defaultdict(list)
for entry in development_data:
    grouped_data_temp[entry["conversationId"]].append(entry)

# Sort each group by timeSent
for conversation_id, conversation in grouped_data_temp.items():
    conversation.sort(key=lambda x: datetime.strptime(x["timeSent"], "%Y-%m-%dT%H:%M:%S.%fZ"))

grouped_data = dict(grouped_data_temp)
list(grouped_data.keys())[0], grouped_data[list(grouped_data.keys())[0]]  # Displaying the first 5 keys and total number of unique conversations for reference
# Out:
# ('c9175fb9-1f09-49c5-bed2-593921504b5a',
#  [{'_id': '65039c6f4210447e1d2f1946',
#    'id': '81c67ab9-fe85-426f-8d82-5a775ed0edee',
#    'role': 'user',
#    'chatgptMessage': {'role': 'user', 'content': 'To build a new app '},
#    'openpluginNamespace': None,
#    'error': None,
#    'timeSent': '2023-09-14T23:51:12.048Z',
#    'timeComplete': '2023-09-14T23:51:12.048Z',
#    'conversationId': 'c9175fb9-1f09-49c5-bed2-593921504b5a',
#    'user_id': '64bf281578f994e79e237dcb'},
#   {'_id': '65039c7ff360b3d5defdef9e',
#    'id': '0785053e-7b17-4694-90c9-9d527713ab14',
#    'role': 'assistant',
#    'chatgptMessage': {'role': 'assistant',
#     'content': "To build a new app, you will need to follow these steps:\n\n1. Define the purpose and target audience of your app: Determine what problem your app will solve and who will benefit from using it. This will help you create a clear vision for your app.\n\n2. Conduct market research: Analyze the existing apps in the market that are similar to your idea. Identify their strengths and weaknesses to understand how you can differentiate your app and provide a better user experience.\n\n3. Create a wireframe or prototype: Sketch out the basic layout and functionality of your app. This will help you visualize the user interface and user experience before moving on to development.\n\n4. Design the user interface (UI): Create a visually appealing and intuitive UI design for your app. Consider the branding, color scheme, typography, and overall aesthetics to create a consistent and engaging user experience.\n\n5. Develop the app: Choose the appropriate technology stack and programming language for your app. If you have coding skills, you can develop the app yourself. Otherwise, you can hire a development team or outsource the development work.\n\n6. Test the app: Conduct thorough testing to identify and fix any bugs or issues. Test the app on different devices and operating systems to ensure compatibility and smooth performance.\n\n7. Launch the app: Prepare for the app launch by creating an app store account, optimizing the app store listing, and creating a marketing strategy to promote your app.\n\n8. Gather user feedback: Once your app is live, encourage users to provide feedback and reviews. This will help you understand how users are interacting with your app and identify areas for improvement.\n\n9. Update and maintain the app: Continuously update your app to fix bugs, add new features, and improve the overall user experience. Regular maintenance is crucial to keep your app relevant and competitive in the market.\n\nRemember, building an app is an iterative process, and it's important to listen to user feedback and adapt accordingly."},
#    'openpluginNamespace': None,
#    'error': None,
#    'timeSent': '2023-09-14T23:51:12.058Z',
#    'timeComplete': '2023-09-14T23:51:27.738Z',
#    'conversationId': 'c9175fb9-1f09-49c5-bed2-593921504b5a',
#    'user_id': '64bf281578f994e79e237dcb'},
#   {'_id': '65039cd8f360b3d5defdef9f',
#    'id': '2f441e61-c9bc-4d9b-930a-33f03849ad9f',
#    'role': 'user',
#    'chatgptMessage': {'role': 'user',
#     'content': 'What is this website about https://www.openplugin.io/'},
#    'openpluginNamespace': 'BrowserOp',
#    'error': None,
#    'timeSent': '2023-09-14T23:52:56.290Z',
#    'timeComplete': '2023-09-14T23:52:56.290Z',
#    'conversationId': 'c9175fb9-1f09-49c5-bed2-593921504b5a',
#    'user_id': '64bf281578f994e79e237dcb'},
#   {'_id': '65039cdcf360b3d5defdefa0',
#    'id': 'd53f2171-57e6-49d3-9bf7-e02024eb3cac',
#    'role': 'function',
#    'chatgptMessage': {'content': '{"result": {"title": "Democratizing ChatGPT and LLM Plugins", "content": "OpenPlugin\\nOpenPlugin is a ChatGPT based chatbot that specializes on leveraging plugins (\\ntools for the AI\\n) to provide a more capable chatbot.\\nSign up for closed beta\\nJoin our\\nDiscord\\nor visit our\\nGitHub\\n!\\nBelow is a form disguised as a chatbot. It is not OpenPlugin.\\nHi and welcome to OpenPlugin!\\nWe are currently hard at working towards the openplugin.io official lanch.\\nFor the time being we are in closed beta, to get access to it,\\nplease share your email\\n(or some other contact information) and we will be in touch with you shortly. If you already have an access key\\nplease enter your access key\\nbelow.\\nSend\\n", "rules": ["Use the language that the user previously used or the language requested by the user.", "Based on the provided data (and all historical retrieved data if the results need more than 1 requests to be completely provided), respond to the user\'s request. No need to include other irrelevant words in your answer.", "Always extract url or source from provided content as a support for your answer.", "Ensure the information provided is accurate, clear, and concise. Avoid overly complex or lengthy explanations when a simple, direct response will suffice, while in the meantime, make sure to provide all the information the user will find valuable based on your correct understanding of user\'s intention. ", "If a conclusive answer cannot be generated based on the provided content, respond to user\\u2019s query first and then attempt to interpret the user\'s intent and suggest ways for them to refine their query for a more successful result.", "If the provided data includes authoritative source such as [wiki] or [official website], organize the response based primarily on data from these sources.", "If the user\'s query contains a URL, give a brief description of the site and summarize it based on the content of the page."]}, "code": 0}',
#     'name': 'transcodeWebPage',
#     'role': 'function'},
#    'openpluginNamespace': 'BrowserOp',
#    'error': None,
#    'timeSent': '2023-09-14T23:52:56.293Z',
#    'timeComplete': '2023-09-14T23:53:00.484Z',
#    'conversationId': 'c9175fb9-1f09-49c5-bed2-593921504b5a',
#    'user_id': '64bf281578f994e79e237dcb'},
#   {'_id': '65039ce19884d4128adafb2e',
#    'id': '00146076-9396-4551-bf88-eeafc1cd4dd0',
#    'role': 'assistant',
#    'chatgptMessage': {'role': 'assistant',
#     'content': 'The website https://www.openplugin.io/ is about OpenPlugin, a ChatGPT based chatbot that specializes in leveraging plugins (tools for the AI) to provide a more capable chatbot experience. The website offers a closed beta program for users to sign up and gain access to OpenPlugin. They also provide links to their Discord community and GitHub page. The website features a form disguised as a chatbot where users can provide their contact information to request access to the closed beta.'},
#    'openpluginNamespace': 'BrowserOp',
#    'error': None,
#    'timeSent': '2023-09-14T23:53:00.510Z',
#    'timeComplete': '2023-09-14T23:53:05.134Z',
#    'conversationId': 'c9175fb9-1f09-49c5-bed2-593921504b5a',
#    'user_id': '64bf281578f994e79e237dcb'}])

# %%
conversations = []

for conversation_id, conversation in grouped_data.items():
    structured_conversation = {
        "conversationId": conversation_id,
        "conversation": []
    }
    
    for entry in conversation:
        structured_entry = {
            "chatgptMessage": entry["chatgptMessage"],
            "functions": None,
            "timeSent": entry["timeSent"]
        }
        if (entry["openpluginNamespace"] and entry["openpluginNamespace"] in ns_to_function_map):
            structured_entry["functions"] = ns_to_function_map[entry["openpluginNamespace"]]
        
        structured_conversation["conversation"].append(structured_entry)
    
    conversations.append(structured_conversation)

conversations[:1]  # Displaying the first conversation for reference
# Out:
# [{'conversationId': 'c9175fb9-1f09-49c5-bed2-593921504b5a',
#   'conversation': [{'chatgptMessage': {'role': 'user',
#      'content': 'To build a new app '},
#     'functions': None,
#     'timeSent': '2023-09-14T23:51:12.048Z'},
#    {'chatgptMessage': {'role': 'assistant',
#      'content': "To build a new app, you will need to follow these steps:\n\n1. Define the purpose and target audience of your app: Determine what problem your app will solve and who will benefit from using it. This will help you create a clear vision for your app.\n\n2. Conduct market research: Analyze the existing apps in the market that are similar to your idea. Identify their strengths and weaknesses to understand how you can differentiate your app and provide a better user experience.\n\n3. Create a wireframe or prototype: Sketch out the basic layout and functionality of your app. This will help you visualize the user interface and user experience before moving on to development.\n\n4. Design the user interface (UI): Create a visually appealing and intuitive UI design for your app. Consider the branding, color scheme, typography, and overall aesthetics to create a consistent and engaging user experience.\n\n5. Develop the app: Choose the appropriate technology stack and programming language for your app. If you have coding skills, you can develop the app yourself. Otherwise, you can hire a development team or outsource the development work.\n\n6. Test the app: Conduct thorough testing to identify and fix any bugs or issues. Test the app on different devices and operating systems to ensure compatibility and smooth performance.\n\n7. Launch the app: Prepare for the app launch by creating an app store account, optimizing the app store listing, and creating a marketing strategy to promote your app.\n\n8. Gather user feedback: Once your app is live, encourage users to provide feedback and reviews. This will help you understand how users are interacting with your app and identify areas for improvement.\n\n9. Update and maintain the app: Continuously update your app to fix bugs, add new features, and improve the overall user experience. Regular maintenance is crucial to keep your app relevant and competitive in the market.\n\nRemember, building an app is an iterative process, and it's important to listen to user feedback and adapt accordingly."},
#     'functions': None,
#     'timeSent': '2023-09-14T23:51:12.058Z'},
#    {'chatgptMessage': {'role': 'user',
#      'content': 'What is this website about https://www.openplugin.io/'},
#     'functions': [{'name': 'transcodeWebPage',
#       'description': 'Acquire precise webpage details or real-time search engine responses based on user-input content.',
#       'parameters': {'type': 'object',
#        'properties': {'json': {'properties': {'link': {'type': 'string',
#            'description': 'This parameter takes either a URL or a non-URL string. If a URL is given, the model will engage with the designated webpage to collect or interact with its data. If a non-URL string is given, the model will handle it as a search inquiry and try to find related real-time news or information. To guarantee the best results, make sure the input is a valid URL or a succinct search query.'}},
#          'type': 'object'}}}}],
#     'timeSent': '2023-09-14T23:52:56.290Z'},
#    {'chatgptMessage': {'content': '{"result": {"title": "Democratizing ChatGPT and LLM Plugins", "content": "OpenPlugin\\nOpenPlugin is a ChatGPT based chatbot that specializes on leveraging plugins (\\ntools for the AI\\n) to provide a more capable chatbot.\\nSign up for closed beta\\nJoin our\\nDiscord\\nor visit our\\nGitHub\\n!\\nBelow is a form disguised as a chatbot. It is not OpenPlugin.\\nHi and welcome to OpenPlugin!\\nWe are currently hard at working towards the openplugin.io official lanch.\\nFor the time being we are in closed beta, to get access to it,\\nplease share your email\\n(or some other contact information) and we will be in touch with you shortly. If you already have an access key\\nplease enter your access key\\nbelow.\\nSend\\n", "rules": ["Use the language that the user previously used or the language requested by the user.", "Based on the provided data (and all historical retrieved data if the results need more than 1 requests to be completely provided), respond to the user\'s request. No need to include other irrelevant words in your answer.", "Always extract url or source from provided content as a support for your answer.", "Ensure the information provided is accurate, clear, and concise. Avoid overly complex or lengthy explanations when a simple, direct response will suffice, while in the meantime, make sure to provide all the information the user will find valuable based on your correct understanding of user\'s intention. ", "If a conclusive answer cannot be generated based on the provided content, respond to user\\u2019s query first and then attempt to interpret the user\'s intent and suggest ways for them to refine their query for a more successful result.", "If the provided data includes authoritative source such as [wiki] or [official website], organize the response based primarily on data from these sources.", "If the user\'s query contains a URL, give a brief description of the site and summarize it based on the content of the page."]}, "code": 0}',
#      'name': 'transcodeWebPage',
#      'role': 'function'},
#     'functions': [{'name': 'transcodeWebPage',
#       'description': 'Acquire precise webpage details or real-time search engine responses based on user-input content.',
#       'parameters': {'type': 'object',
#        'properties': {'json': {'properties': {'link': {'type': 'string',
#            'description': 'This parameter takes either a URL or a non-URL string. If a URL is given, the model will engage with the designated webpage to collect or interact with its data. If a non-URL string is given, the model will handle it as a search inquiry and try to find related real-time news or information. To guarantee the best results, make sure the input is a valid URL or a succinct search query.'}},
#          'type': 'object'}}}}],
#     'timeSent': '2023-09-14T23:52:56.293Z'},
#    {'chatgptMessage': {'role': 'assistant',
#      'content': 'The website https://www.openplugin.io/ is about OpenPlugin, a ChatGPT based chatbot that specializes in leveraging plugins (tools for the AI) to provide a more capable chatbot experience. The website offers a closed beta program for users to sign up and gain access to OpenPlugin. They also provide links to their Discord community and GitHub page. The website features a form disguised as a chatbot where users can provide their contact information to request access to the closed beta.'},
#     'functions': [{'name': 'transcodeWebPage',
#       'description': 'Acquire precise webpage details or real-time search engine responses based on user-input content.',
#       'parameters': {'type': 'object',
#        'properties': {'json': {'properties': {'link': {'type': 'string',
#            'description': 'This parameter takes either a URL or a non-URL string. If a URL is given, the model will engage with the designated webpage to collect or interact with its data. If a non-URL string is given, the model will handle it as a search inquiry and try to find related real-time news or information. To guarantee the best results, make sure the input is a valid URL or a succinct search query.'}},
#          'type': 'object'}}}}],
#     'timeSent': '2023-09-14T23:53:00.510Z'}]}]

# %%
# iterate through all conversations and messages inside conversations and delete the message if there is no chatgptMessage
for conversation in conversations:
    conversation["conversation"] = [message for message in conversation["conversation"] if message["chatgptMessage"]]

# save
with open(save_to_file, "w") as file:
    json.dump(conversations, file)

# test with conversationId = hX1Dzy

# %%
len(conversations)
# Out:
# 557

# %%
# if there are any conversations that contain a message.chatgptMessage.role "function" whose previous message is not a message.chatgptMessage.role "assistant" with message.chatgptMessage.function_call, then delete the conversation
def delete_conversations_without_required_messages(conversations):
    """
    Delete conversations that do not contain a message with role "assistant" and "function_call" before a message with role "function".
    """
    conversations_to_delete = []
    for conversation in conversations:
        messages = conversation["conversation"]
        for i, message in enumerate(messages):
            if "role" not in message["chatgptMessage"]:
                conversations_to_delete.append(conversation["conversationId"])
                break
            # delete if a function message is not preceeded by a chatgpt assistant function_call
            if message["chatgptMessage"]["role"] == "function":
                if messages[i-1]["chatgptMessage"]["role"] != "assistant" or not messages[i-1]["chatgptMessage"].get("function_call"):
                    conversations_to_delete.append(conversation["conversationId"])
                    break
    return [conversation for conversation in conversations if conversation["conversationId"] not in conversations_to_delete]

conversations = delete_conversations_without_required_messages(conversations)

with open(save_to_file, "w") as file:
    json.dump(conversations, file)
# test with conversationId = ea463f0e-9cd1-4af6-87d1-8e722334b97b

# %%
len(conversations)
# Out:
# 514

# %%
def reorder_function_call_exchange(conversations):
    """
    Reorder instances where a "function" message is followed by an "assistant" message containing a "function_call".
    The "assistant" message will be moved to precede the "function" message.
    """
    for conversation in conversations:
        messages = conversation["conversation"]
        i = 0
        while i < len(messages) - 1:
            current_message = messages[i]
            next_message = messages[i+1]
            
            # Check for the specified sequence of "function" followed by "assistant" with "function_call"
            if (current_message["chatgptMessage"]["role"] == "function" and
                next_message["chatgptMessage"]["role"] == "assistant" and
                "function_call" in next_message["chatgptMessage"]):
                # Swap the messages
                messages[i], messages[i+1] = messages[i+1], messages[i]
                i += 2  # Skip the next message since we just swapped
            else:
                i += 1
    return conversations

conversations = reorder_function_call_exchange(conversations)

with open(save_to_file, "w") as file:
    json.dump(conversations, file)

# test with conversationId = 453e1f54-b604-4e0e-aa85-21febce5d6a4

# %%
len(conversations)  # Check the number of conversations
# Out:
# 514

# %%
conversations[310]
# Out:
# {'conversationId': 'bd689eb1-8fe2-4bc5-9086-822fd7ac0364',
#  'conversation': [{'chatgptMessage': {'role': 'user',
#     'content': 'Show me 3 scholarly articles on Large Language Models'},
#    'functions': [{'name': 'searchArxiv',
#      'description': 'Search Arxiv',
#      'parameters': {'type': 'object',
#       'properties': {'path_params': {'type': 'object',
#         'properties': {'content': {'type': 'string',
#           'description': 'The search query is generally in English. If it is not, please translate it into English first.'}},
#         'required': ['content']}}}}],
#    'timeSent': '2023-10-17T14:21:10.515Z'},
#   {'chatgptMessage': {'content': None,
#     'function_call': {'arguments': '{}', 'name': 'searchArxiv'},
#     'role': 'assistant'},
#    'functions': [{'name': 'searchArxiv',
#      'description': 'Search Arxiv',
#      'parameters': {'type': 'object',
#       'properties': {'path_params': {'type': 'object',
#         'properties': {'content': {'type': 'string',
#           'description': 'The search query is generally in English. If it is not, please translate it into English first.'}},
#         'required': ['content']}}}}],
#    'timeSent': '2023-10-17T14:21:15.199Z'},
#   {'chatgptMessage': {'content': '[]',
#     'name': 'searchArxiv',
#     'role': 'function'},
#    'functions': [{'name': 'searchArxiv',
#      'description': 'Search Arxiv',
#      'parameters': {'type': 'object',
#       'properties': {'path_params': {'type': 'object',
#         'properties': {'content': {'type': 'string',
#           'description': 'The search query is generally in English. If it is not, please translate it into English first.'}},
#         'required': ['content']}}}}],
#    'timeSent': '2023-10-17T14:21:10.516Z'},
#   {'chatgptMessage': {'role': 'user', 'content': 'j'},
#    'functions': [{'name': 'transcodeWebPage',
#      'description': 'Acquire precise webpage details or real-time search engine responses based on user-input content.',
#      'parameters': {'type': 'object',
#       'properties': {'json': {'properties': {'link': {'type': 'string',
#           'description': 'This parameter takes either a URL or a non-URL string. If a URL is given, the model will engage with the designated webpage to collect or interact with its data. If a non-URL string is given, the model will handle it as a search inquiry and try to find related real-time news or information. To guarantee the best results, make sure the input is a valid URL or a succinct search query.'}},
#         'type': 'object'}}}}],
#    'timeSent': '2023-10-17T14:21:48.633Z'},
#   {'chatgptMessage': {'role': 'assistant',
#     'content': 'I\'m sorry, but I\'m not sure what you mean by "j". Could you please provide more context or clarify your request?'},
#    'functions': [{'name': 'transcodeWebPage',
#      'description': 'Acquire precise webpage details or real-time search engine responses based on user-input content.',
#      'parameters': {'type': 'object',
#       'properties': {'json': {'properties': {'link': {'type': 'string',
#           'description': 'This parameter takes either a URL or a non-URL string. If a URL is given, the model will engage with the designated webpage to collect or interact with its data. If a non-URL string is given, the model will handle it as a search inquiry and try to find related real-time news or information. To guarantee the best results, make sure the input is a valid URL or a succinct search query.'}},
#         'type': 'object'}}}}],
#    'timeSent': '2023-10-17T14:21:52.128Z'},
#   {'chatgptMessage': {'role': 'user', 'content': 'what is adderall'},
#    'functions': [{'name': 'transcodeWebPage',
#      'description': 'Acquire precise webpage details or real-time search engine responses based on user-input content.',
#      'parameters': {'type': 'object',
#       'properties': {'json': {'properties': {'link': {'type': 'string',
#           'description': 'This parameter takes either a URL or a non-URL string. If a URL is given, the model will engage with the designated webpage to collect or interact with its data. If a non-URL string is given, the model will handle it as a search inquiry and try to find related real-time news or information. To guarantee the best results, make sure the input is a valid URL or a succinct search query.'}},
#         'type': 'object'}}}}],
#    'timeSent': '2023-10-17T14:22:10.876Z'},
#   {'chatgptMessage': {'content': None,
#     'function_call': {'arguments': '{"json": {"link": "https://www.webmd.com/drugs/2/drug-63163/adderall-oral/details"}}',
#      'name': 'transcodeWebPage'},
#     'role': 'assistant'},
#    'functions': [{'name': 'transcodeWebPage',
#      'description': 'Acquire precise webpage details or real-time search engine responses based on user-input content.',
#      'parameters': {'type': 'object',
#       'properties': {'json': {'properties': {'link': {'type': 'string',
#           'description': 'This parameter takes either a URL or a non-URL string. If a URL is given, the model will engage with the designated webpage to collect or interact with its data. If a non-URL string is given, the model will handle it as a search inquiry and try to find related real-time news or information. To guarantee the best results, make sure the input is a valid URL or a succinct search query.'}},
#         'type': 'object'}}}}],
#    'timeSent': '2023-10-17T14:22:15.952Z'},
#   {'chatgptMessage': {'content': '{"result": {"content": "MENU\\nDRUGS AND MEDICATIONS CENTER\\nFind a Drug\\nMy Medicine\\nPill Identifier\\nInteraction Checker\\nFind a Vitamin\\nFind a Pharmacy\\nVITAMINS & SUPPLEMENTS CENTER\\nFind a Vitamin or Supplement\\nVitamin Lifestyle Guide\\nAssess Your Vitamin Needs\\nFIRST AID RESOURCES\\nFirst Aid Home\\nFirst Aid Kit & Wound Care\\nFirst Aid Mobile\\nDrugs & Medications\\nAdderall\\nUses\\nSide Effects\\nWarnings\\nPrecautions\\nInteractions\\nOverdose\\nImages\\nReviews (1675)\\nThis combination\\nmedication\\nis used to treat\\nattention deficit hyperactivity disorder\\n-\\nADHD\\n. It works by changing the amounts of certain natural substances in the\\nbrain\\n.\\nAmphetamine\\n/\\ndextroamphetamine\\nbelongs to a class of drugs known as stimulants. It can help increase your ability to pay attention, stay focused on an activity, and control behavior problems. It may also help you to organize your tasks and improve listening skills.This drug is also used to treat a certain sleeping disorder (\\nnarcolepsy\\n) to help you stay awake during the day. It should not be used to treat tiredness or to hold off\\nsleep\\nin people who do not have a\\nsleep disorder\\nHow to use Adderall\\nRead the\\nMedication\\nGuide provided by your\\npharmacist\\nbefore you start taking\\namphetamine\\nand each time you get a refill. If you have any questions, ask your doctor or pharmacist.\\nTake this medication by\\nmouth\\nwith or without food as directed by your doctor, usually 1 to 3 times a day. The first dose is usually taken when you wake up in the morning. If more doses are prescribed, take them as directed by your doctor, usually 4-6 hours apart. Taking this medication late in the day may cause\\ntrouble sleeping\\n(\\ninsomnia\\n).\\nThe dosage is based on your medical condition and response to treatment. Your doctor may adjust your dose to find the dose that is best for you. Follow your doctor\'s instructions carefully.\\nUse this medication regularly to get the most benefit from it. To help you remember, take it at the same time(s) each day.\\nDuring treatment, your doctor may occasionally recommend stopping the medication for a short time to see whether there are any changes in your behavior and whether the medication is still needed.\\nIf you suddenly stop using this medication, you may have withdrawal symptoms (such as severe tiredness,\\nproblems, mental/mood changes such as\\ndepression\\n). To help prevent withdrawal, your doctor may lower your dose slowly. Withdrawal is more likely if you have used this medication for a long time or in high doses. Tell your doctor or pharmacist right away if you have withdrawal.\\nThough it helps many people, this medication may sometimes cause addiction. This risk may be higher if you have a substance use disorder (such as overuse of or addiction to drugs/alcohol). Do not increase your dose, take it more often, or use it for a longer time than prescribed. Properly stop the medication when so directed.\\nWhen this medication is used for a long time, it may not work as well. Talk with your doctor if this medication stops working well.\\nTell your doctor if your condition does not improve or if it worsens.\\nLoss of appetite,\\nweight loss\\n,\\ndry mouth\\nstomach\\nupset/pain,\\nnausea\\nvomiting\\ndizziness\\nheadache\\ndiarrhea\\n, fever, nervousness, and\\nmay occur. If any of these effects last or get worse, tell your doctor promptly.\\nRemember that this\\nhas been prescribed because your doctor has judged that the benefit to you is greater than the risk of side effects. Many people using this medication do not have serious side effects.\\nThis medication may raise your\\nblood pressure\\n. Check your\\nblood\\npressure regularly and tell your doctor if the results are high.\\nTell your doctor right away if you have any serious side effects, including: signs of blood flow problems in the fingers or toes (such as coldness, numbness, pain, or ...
#     'name': 'transcodeWebPage',
#     'role': 'function'},
#    'functions': [{'name': 'transcodeWebPage',
#      'description': 'Acquire precise webpage details or real-time search engine responses based on user-input content.',
#      'parameters': {'type': 'object',
#       'properties': {'json': {'properties': {'link': {'type': 'string',
#           'description': 'This parameter takes either a URL or a non-URL string. If a URL is given, the model will engage with the designated webpage to collect or interact with its data. If a non-URL string is given, the model will handle it as a search inquiry and try to find related real-time news or information. To guarantee the best results, make sure the input is a valid URL or a succinct search query.'}},
#         'type': 'object'}}}}],
#    'timeSent': '2023-10-17T14:22:10.876Z'},
#   {'chatgptMessage': {'role': 'assistant',
#     'content': "Adderall is a combination medication that is commonly used to treat attention deficit hyperactivity disorder (ADHD) and narcolepsy. It contains amphetamine and dextroamphetamine, which are stimulant drugs that work by changing the levels of certain natural substances in the brain. Adderall helps increase attention, focus, and control behavior problems in individuals with ADHD. It may also be used to help individuals with narcolepsy stay awake during the day.\n\nAdderall is typically taken orally, with or without food, as directed by a doctor. The dosage is based on the individual's medical condition and response to treatment. It is important to follow the doctor's instructions carefully and take the medication regularly to get the most benefit from it.\n\nLike any medication, Adderall may cause side effects, including loss of appetite, weight loss, dry mouth, upset stomach, nausea, vomiting, dizziness, headache, diarrhea, fever, nervousness, and trouble sleeping. Serious side effects may include changes in blood pressure, signs of blood flow problems in the fingers or toes, mental/mood/behavior changes, uncontrolled movements, abnormal thoughts, seizures, and serotonin syndrome. It is important to consult a doctor if any serious side effects occur.\n\nAdderall can be habit-forming and may cause dependence or withdrawal symptoms if used for a long time. It is essential to use the medication only as directed by a healthcare professional. Before taking Adderall, it is important to inform the doctor about any allergies, medical history, and current medications being taken.\n\nPlease note that this is a brief overview of Adderall, and it is important to consult a healthcare professional or refer to the medication guide for more detailed information and guidance."},
#    'functions': [{'name': 'transcodeWebPage',
#      'description': 'Acquire precise webpage details or real-time search engine responses based on user-input content.',
#      'parameters': {'type': 'object',
#       'properties': {'json': {'properties': {'link': {'type': 'string',
#           'description': 'This parameter takes either a URL or a non-URL string. If a URL is given, the model will engage with the designated webpage to collect or interact with its data. If a non-URL string is given, the model will handle it as a search inquiry and try to find related real-time news or information. To guarantee the best results, make sure the input is a valid URL or a succinct search query.'}},
#         'type': 'object'}}}}],
#    'timeSent': '2023-10-17T14:22:15.956Z'},
#   {'chatgptMessage': {'role': 'user', 'content': 'what is amphetamine'},
#    'functions': [{'name': 'transcodeWebPage',
#      'description': 'Acquire precise webpage details or real-time search engine responses based on user-input content.',
#      'parameters': {'type': 'object',
#       'properties': {'json': {'properties': {'link': {'type': 'string',
#           'description': 'This parameter takes either a URL or a non-URL string. If a URL is given, the model will engage with the designated webpage to collect or interact with its data. If a non-URL string is given, the model will handle it as a search inquiry and try to find related real-time news or information. To guarantee the best results, make sure the input is a valid URL or a succinct search query.'}},
#         'type': 'object'}}}}],
#    'timeSent': '2023-10-17T14:25:25.900Z'},
#   {'chatgptMessage': {'role': 'assistant',
#     'content': "Amphetamine is a central nervous system (CNS) stimulant drug that affects chemicals in the brain and nerves that contribute to hyperactivity and impulse control. It belongs to a class of drugs called amphetamines, which also includes dextroamphetamine and methamphetamine.\n\nAmphetamines like amphetamine are commonly used to treat attention deficit hyperactivity disorder (ADHD) and narcolepsy. They work by increasing the levels of certain neurotransmitters, such as dopamine and norepinephrine, in the brain. This helps to improve focus, attention, and impulse control in individuals with ADHD. In the case of narcolepsy, amphetamines can help to reduce excessive daytime sleepiness and improve wakefulness.\n\nAmphetamine is typically taken orally, in the form of tablets or capsules, and the dosage is determined by a healthcare professional based on the individual's condition and response to treatment. It is important to follow the prescribed dosage and instructions carefully.\n\nLike any medication, amphetamine may cause side effects. Common side effects include increased heart rate, increased blood pressure, decreased appetite, weight loss, insomnia, dry mouth, and irritability. Serious side effects may include chest pain, shortness of breath, severe headache, blurred vision, seizures, and signs of circulation problems. It is important to seek medical attention if any serious side effects occur.\n\nAmphetamines can be habit-forming and may cause dependence or withdrawal symptoms if used for a long time. It is important to use the medication only as directed by a healthcare professional and to follow any tapering instructions when discontinuing its use.\n\nIt is important to note that this is a general overview of amphetamine, and it is essential to consult a healthcare professional or refer to the medication guide for more detailed information and guidance."},
#    'functions': [{'name': 'transcodeWebPage',
#      'description': 'Acquire precise webpage details or real-time search engine responses based on user-input content.',
#      'parameters': {'type': 'object',
#       'properties': {'json': {'properties': {'link': {'type': 'string',
#           'description': 'This parameter takes either a URL or a non-URL string. If a URL is given, the model will engage with the designated webpage to collect or interact with its data. If a non-URL string is given, the model will handle it as a search inquiry and try to find related real-time news or information. To guarantee the best results, make sure the input is a valid URL or a succinct search query.'}},
#         'type': 'object'}}}}],
#    'timeSent': '2023-10-17T14:25:36.054Z'},
#   {'chatgptMessage': {'role': 'user', 'content': 'weather calgary'},
#    'functions': [{'name': 'transcodeWebPage',
#      'description': 'Acquire precise webpage details or real-time search engine responses based on user-input content.',
#      'parameters': {'type': 'object',
#       'properties': {'json': {'properties': {'link': {'type': 'string',
#           'description': 'This parameter takes either a URL or a non-URL string. If a URL is given, the model will engage with the designated webpage to collect or interact with its data. If a non-URL string is given, the model will handle it as a search inquiry and try to find related real-time news or information. To guarantee the best results, make sure the input is a valid URL or a succinct search query.'}},
#         'type': 'object'}}}}],
#    'timeSent': '2023-10-17T14:27:05.580Z'},
#   {'chatgptMessage': {'content': None,
#     'function_call': {'arguments': '{"json": {"link": "https://www.google.com/search?q=weather+calgary"}}',
#      'name': 'transcodeWebPage'},
#     'role': 'assistant'},
#    'functions': [{'name': 'transcodeWebPage',
#      'description': 'Acquire precise webpage details or real-time search engine responses based on user-input content.',
#      'parameters': {'type': 'object',
#       'properties': {'json': {'properties': {'link': {'type': 'string',
#           'description': 'This parameter takes either a URL or a non-URL string. If a URL is given, the model will engage with the designated webpage to collect or interact with its data. If a non-URL string is given, the model will handle it as a search inquiry and try to find related real-time news or information. To guarantee the best results, make sure the input is a valid URL or a succinct search query.'}},
#         'type': 'object'}}}}],
#    'timeSent': '2023-10-17T14:27:12.785Z'},
#   {'chatgptMessage': {'content': '{"result": {"title": "weather calgary", "content": "All\\nNews\\nImages\\nBooks\\nMaps\\nVideos\\nShopping\\nSearch tools\\nAny time\\nPast hour\\nPast 24 hours\\nPast week\\nPast month\\nPast year\\nAll results\\nVerbatim\\nCalgary, AB, Canada\\n/\\nWeather\\n47\\u00b0F\\nTuesday 8:27\\u202fAM Light rain showers\\nMore on weather.com\\nCalgary, Alberta, Canada 10-Day Weather Forecast\\nweather.com \\u203a weather \\u203a tenday \\u203a CAXX0054:1:CA\\n10 Day Weather-Calgary, Alberta, Canada. As of 8:58 pm MDT. Tonight. --/43\\u00b0. 7%. Sat 14 | Night. 43\\u00b0. 7%. WSW 6 mph. Some clouds. Low 43F.\\nCurrent Weather - Calgary - The Weather Network\\nwww.theweathernetwork.com \\u203a weather \\u203a alberta \\u203a calgary\\nGet Calgary, AB current weather report with temperature, feels like, air quality, humidity, UV report and pollen forecast from TheWeatherNetwork.com.\\n14 Day Trend\\n\\u00b7\\n7 Days\\nHourly\\nAir Quality Health Index (AQHI)\\nPeople also ask\\nWhat\'s the coldest month in Calgary?\\nWhich month is the hottest in Calgary?\\nIs Calgary good place to live?\\nDoes Calgary get snow storms?\\nCalgary, AB - 7 Day Forecast - Environment Canada\\nweather.gc.ca \\u203a city \\u203a pages \\u203a ab-52_metric_e\\nCloudy. 30 percent chance of showers early in the morning. Becoming a mix of sun and cloud late in the morning. Wind northwest 30 km/h gusting to 50.\\nHourly Forecast\\nAir Quality\\nAlmanac Averages and...\\nCalgary, Alberta, Canada Weather Forecast - AccuWeather\\nwww.accuweather.com \\u203a calgary \\u203a weather-forecast\\nCalgary, Alberta, Canada Weather Forecast, with current conditions, wind, air quality, and what to expect for the next 3 days.\\nCalgary, Alberta, Canada 14 day weather forecast - Time and Date\\nwww.timeanddate.com \\u203a Weather \\u203a Canada \\u203a Calgary\\nCalgary Extended Forecast with high and low temperatures ; Oct 15 \\u2013 Oct 21. Lo:52. Mon, 16 ; 0.05. Lo:41. Tue, 17 ; Lo:37. Wed, 18 ; Lo:41. Thu, 19 ; Lo:40. Fri, 20.\\nCalgary - BBC Weather\\nwww.bbc.com \\u203a weather\\nHour by hour forecast ; 11 \\u00b7 44\\u00b0 \\u00b7 73% \\u00b7 5\\u00b041\\u00b0 ; 12 \\u00b7 47\\u00b0 \\u00b7 66% \\u00b7 7\\u00b044\\u00b0 ; 13 \\u00b7 50\\u00b0 \\u00b7 57% \\u00b7 9\\u00b047\\u00b0.\\nCalgary Weather | Southern Alberta Forecasts\\ncalgary.ctvnews.ca \\u203a weather\\nThe latest five-day weather forecasts, current temperatures, alerts and more from David Spence and Kevin Stanfield in the CTV News Calgary Sky Watch Weather\\u00a0...\\nCalgary (Canada) weather - Met Office\\nwww.metoffice.gov.uk \\u203a weather \\u203a forecast\\nSeven day forecast for Calgary ; <5%, <5%, <5%, <5% ; 11\\u00b0. 10\\u00b0. 9\\u00b0. 9\\u00b0.\\nCalgary Weather | Forecast Conditions - Global News\\nglobalnews.ca \\u203a calgary \\u203a weather \\u203a CAXX0054\\nSaturday 10\\u00b0 3\\u00b0 Mostly cloudy. Highs 9 to 11C and lows 2 to 4C. Sunday 9\\u00b0 0\\u00b0 Showers. Highs 8 to 10C and lows -1 to 1C. Monday 4\\u00b0 -4\\u00b0 Mix of rain and snow\\u00a0...\\nCBC News - Local Weather - Calgary, Alberta\\nwww.cbc.ca \\u203a weather\\nTuesday. Cloudy. 30 percent chance of showers early in the morning. Becoming a mix of sun and cloud late in the morning. Wind northwest 20 km/h gusting to\\u00a0...\\nRelated searches\\nWeather in Calgary 10 days\\nWeather in Calgary tomorrow\\nCalgary weather 14 day\\nCalgary weather 30 days\\nWeather Edmonton\\nWeather banff\\nCalgary weather 7 day\\nCalgary weather hourly\\n", "rules": ["Use the language that the user previously used or the language requested by the user.", "Based on the provided data (and all historical retrieved data if the results need more than 1 requests to be completely provided), respond to the user\'s request. No need to include other irrelevant words in your answer.", "Always extract url or source from provided content as a support for your answer.", "Ensure the information provided is accurate, clear,  ...
#     'name': 'transcodeWebPage',
#     'role': 'function'},
#    'functions': [{'name': 'transcodeWebPage',
#      'description': 'Acquire precise webpage details or real-time search engine responses based on user-input content.',
#      'parameters': {'type': 'object',
#       'properties': {'json': {'properties': {'link': {'type': 'string',
#           'description': 'This parameter takes either a URL or a non-URL string. If a URL is given, the model will engage with the designated webpage to collect or interact with its data. If a non-URL string is given, the model will handle it as a search inquiry and try to find related real-time news or information. To guarantee the best results, make sure the input is a valid URL or a succinct search query.'}},
#         'type': 'object'}}}}],
#    'timeSent': '2023-10-17T14:27:05.581Z'},
#   {'chatgptMessage': {'role': 'assistant',
#     'content': 'The current weather in Calgary, AB, Canada is 47°F with light rain showers. For more detailed information, you can check out various weather forecast websites such as [weather.com](https://www.weather.com), [The Weather Network](https://www.theweathernetwork.com), and [Environment Canada](https://weather.gc.ca).'},
#    'functions': [{'name': 'transcodeWebPage',
#      'description': 'Acquire precise webpage details or real-time search engine responses based on user-input content.',
#      'parameters': {'type': 'object',
#       'properties': {'json': {'properties': {'link': {'type': 'string',
#           'description': 'This parameter takes either a URL or a non-URL string. If a URL is given, the model will engage with the designated webpage to collect or interact with its data. If a non-URL string is given, the model will handle it as a search inquiry and try to find related real-time news or information. To guarantee the best results, make sure the input is a valid URL or a succinct search query.'}},
#         'type': 'object'}}}}],
#    'timeSent': '2023-10-17T14:27:12.791Z'},
#   {'chatgptMessage': {'role': 'user', 'content': 'in c'},
#    'functions': [{'name': 'transcodeWebPage',
#      'description': 'Acquire precise webpage details or real-time search engine responses based on user-input content.',
#      'parameters': {'type': 'object',
#       'properties': {'json': {'properties': {'link': {'type': 'string',
#           'description': 'This parameter takes either a URL or a non-URL string. If a URL is given, the model will engage with the designated webpage to collect or interact with its data. If a non-URL string is given, the model will handle it as a search inquiry and try to find related real-time news or information. To guarantee the best results, make sure the input is a valid URL or a succinct search query.'}},
#         'type': 'object'}}}}],
#    'timeSent': '2023-10-17T14:27:21.895Z'},
#   {'chatgptMessage': {'role': 'assistant',
#     'content': 'The current weather in Calgary, AB, Canada is approximately 8.3°C with light rain showers.'},
#    'functions': [{'name': 'transcodeWebPage',
#      'description': 'Acquire precise webpage details or real-time search engine responses based on user-input content.',
#      'parameters': {'type': 'object',
#       'properties': {'json': {'properties': {'link': {'type': 'string',
#           'description': 'This parameter takes either a URL or a non-URL string. If a URL is given, the model will engage with the designated webpage to collect or interact with its data. If a non-URL string is given, the model will handle it as a search inquiry and try to find related real-time news or information. To guarantee the best results, make sure the input is a valid URL or a succinct search query.'}},
#         'type': 'object'}}}}],
#    'timeSent': '2023-10-17T14:27:26.353Z'},
#   {'chatgptMessage': {'role': 'user',
#     'content': 'find me the best github projects related to chatgpt frontends'},
#    'functions': [{'name': 'transcodeWebPage',
#      'description': 'Acquire precise webpage details or real-time search engine responses based on user-input content.',
#      'parameters': {'type': 'object',
#       'properties': {'json': {'properties': {'link': {'type': 'string',
#           'description': 'This parameter takes either a URL or a non-URL string. If a URL is given, the model will engage with the designated webpage to collect or interact with its data. If a non-URL string is given, the model will handle it as a search inquiry and try to find related real-time news or information. To guarantee the best results, make sure the input is a valid URL or a succinct search query.'}},
#         'type': 'object'}}}}],
#    'timeSent': '2023-10-17T14:28:01.409Z'},
#   {'chatgptMessage': {'content': None,
#     'function_call': {'arguments': '{"json": {"link": "https://github.com/search?q=chatgpt+frontend"}}',
#      'name': 'transcodeWebPage'},
#     'role': 'assistant'},
#    'functions': [{'name': 'transcodeWebPage',
#      'description': 'Acquire precise webpage details or real-time search engine responses based on user-input content.',
#      'parameters': {'type': 'object',
#       'properties': {'json': {'properties': {'link': {'type': 'string',
#           'description': 'This parameter takes either a URL or a non-URL string. If a URL is given, the model will engage with the designated webpage to collect or interact with its data. If a non-URL string is given, the model will handle it as a search inquiry and try to find related real-time news or information. To guarantee the best results, make sure the input is a valid URL or a succinct search query.'}},
#         'type': 'object'}}}}],
#    'timeSent': '2023-10-17T14:28:08.954Z'},
#   {'chatgptMessage': {'content': '{"result": {"title": "Repository search results \\u00b7", "content": "Skip to content\\nYou signed in with another tab or window.\\nReload\\nto refresh your session.\\nYou signed out in another tab or window.\\nYou switched accounts on another tab or window.\\nDismiss alert\\n{{ message }}\\nrepositories\\nSearch Results\\n\\u00b7 chatgpt frontend\\nPane width\\nUse a value between\\n0\\n% and\\n%\\nChange width\\nFilter by\\nCode\\n...\\n\\u00a0(\\n)\\nRepositories\\nIssues\\nPull requests\\nDiscussions\\nUsers\\nMore\\nLanguages\\n\\u200e\\nJavaScript\\nTypeScript\\nCSS\\nPython\\nVue\\nHTML\\nRust\\nJava\\nC#\\nGo\\nMore languages...\\nAdvanced\\nOwner\\nSize\\nNumber of followers\\nNumber of forks\\nNumber of stars\\nDate created\\nDate pushed\\nTopic\\nLicense\\nArchived\\nPublic\\nPrivate\\nAdvanced search\\n0 results\\n245\\nms\\nSort by:\\nBest match\\nFilter\\nFront end\\nFront end is the programming and layout that people see and interact with.\\nWikipedia\\nView topic\\nObservedObserver/\\nchatgpt\\n-i18n\\nLocalize your websites with AI assistance.\\ni18n\\nai\\nfrontend\\ngpt\\n\\u00b7\\n698\\nUpdated\\non Jun 15\\nStar\\nKudoAI/\\n.js\\n\\ud83e\\udd16 A powerful, open source client-side JavaScript library for\\nChatGPT\\njavascript\\nnlp\\nchat\\nbot\\nmachine-learning\\n1.5k\\n16 hours ago\\nlongern/\\n-api-\\nFrontend\\nof\\nAPI\\nreact\\nwebsite\\nchatgpt-api\\n40\\non Mar 28\\ncookeem/\\n-stream\\nReal-time\\nservice, support GPT3/GPT4, support conversation and generate pictures from sentences, this is\\nwebsocket\\nvue\\nrealtime\\ngpt4\\n85\\non Mar 23\\npashpashpash/vault-ai\\nOP Vault\\n: Give\\nlong-term memory using the OP Stack (OpenAI + Pinecone Vector Database). Upload your own custom knowledge \\u2026\\ngo\\ngolang\\n3.1k\\non Aug 15\\nMoonKraken/rusty_llama\\nA simple\\nclone in Rust on both the\\nand backend. Uses open source language models and TailwindCSS.\\n237\\n8 days ago\\ndtinth/ThreadGPT\\nAlternative\\nto\\n(gpt-3.5-turbo / gpt-4) with a thread-based interface\\n75\\non Apr 8\\nDhruvgera/LocalAI-\\nA front-end for selfhosted LLMs based on the LocalAI API\\nselfhosted\\nllm\\n38\\non Aug 7\\njmpaz/promptlib\\nA collection of prompts for use with GPT-4 via\\n, OpenAI API w/ Gradio\\n& notebook\\nopenai\\ngradio\\nprompts\\ngpt-3\\ngpt-4\\nJupyter Notebook\\n167\\non Aug 8\\ntohrxyz/\\n-open-ui\\nAn Open UI\\nfor\\nreactjs\\nwebapp\\n17\\non Mar 19\\nSponsor open source projects you depend on\\nContributors are working behind the scenes to make open source better for everyone\\u2014give them the help and recognition they deserve.\\nExplore sponsorable projects\\nProTip!\\n\\u00a0\\nPress the\\n/\\nkey to activate the search input again and adjust your query.\\nYou can\\u2019t perform that action at this time.\\n", "rules": ["Use the language that the user previously used or the language requested by the user.", "Based on the provided data (and all historical retrieved data if the results need more than 1 requests to be completely provided), respond to the user\'s request. No need to include other irrelevant words in your answer.", "Always extract url or source from provided content as a support for your answer.", "Ensure the information provided is accurate, clear, and concise. Avoid overly complex or lengthy explanations when a simple, direct response will suffice, while in the meantime, make sure to provide all the information the user will find valuable based on your correct understanding of user\'s intention. ", "If a conclusive answer cannot be generated based on the provided content, respond to user\\u2019s query first and then attempt to interpret the user\'s intent and suggest ways for them to refine their query for a more successful result.", "If the provided data includes authoritative source such as [wiki] or [official website], organize the response based primarily on data from these sources.", "If the user\'s query contains a URL, give a brief d ...
#     'name': 'transcodeWebPage',
#     'role': 'function'},
#    'functions': [{'name': 'transcodeWebPage',
#      'description': 'Acquire precise webpage details or real-time search engine responses based on user-input content.',
#      'parameters': {'type': 'object',
#       'properties': {'json': {'properties': {'link': {'type': 'string',
#           'description': 'This parameter takes either a URL or a non-URL string. If a URL is given, the model will engage with the designated webpage to collect or interact with its data. If a non-URL string is given, the model will handle it as a search inquiry and try to find related real-time news or information. To guarantee the best results, make sure the input is a valid URL or a succinct search query.'}},
#         'type': 'object'}}}}],
#    'timeSent': '2023-10-17T14:28:01.410Z'},
#   {'chatgptMessage': {'role': 'assistant',
#     'content': "Here are some of the best GitHub projects related to ChatGPT frontends:\n\n1. [ObservedObserver/chatgpt](https://github.com/ObservedObserver/chatgpt): This project is about localizing your websites with AI assistance.\n\n2. [KudoAI/.js](https://github.com/KudoAI/.js): A powerful, open-source client-side JavaScript library for ChatGPT.\n\n3. [longern/-api-](https://github.com/longern/-api-): This is the frontend of API for ChatGPT.\n\n4. [cookeem/-stream](https://github.com/cookeem/-stream): This project is a real-time service, supporting GPT3/GPT4, conversation, and generating pictures from sentences.\n\n5. [pashpashpash/vault-ai](https://github.com/pashpashpash/vault-ai): This project gives long-term memory using the OP Stack (OpenAI + Pinecone Vector Database).\n\n6. [MoonKraken/rusty_llama](https://github.com/MoonKraken/rusty_llama): A simple clone in Rust on both the frontend and backend. Uses open-source language models and TailwindCSS.\n\n7. [dtinth/ThreadGPT](https://github.com/dtinth/ThreadGPT): An alternative to ChatGPT with a thread-based interface.\n\n8. [Dhruvgera/LocalAI-](https://github.com/Dhruvgera/LocalAI-): A front-end for self-hosted LLMs based on the LocalAI API.\n\n9. [jmpaz/promptlib](https://github.com/jmpaz/promptlib): A collection of prompts for use with GPT-4 via ChatGPT, OpenAI API w/ Gradio & notebook.\n\n10. [tohrxyz/-open-ui](https://github.com/tohrxyz/-open-ui): An Open UI frontend for ChatGPT.\n\nPlease note that the popularity and usefulness of these projects can vary, and it's always a good idea to check the latest updates and community feedback before using them."},
#    'functions': [{'name': 'transcodeWebPage',
#      'description': 'Acquire precise webpage details or real-time search engine responses based on user-input content.',
#      'parameters': {'type': 'object',
#       'properties': {'json': {'properties': {'link': {'type': 'string',
#           'description': 'This parameter takes either a URL or a non-URL string. If a URL is given, the model will engage with the designated webpage to collect or interact with its data. If a non-URL string is given, the model will handle it as a search inquiry and try to find related real-time news or information. To guarantee the best results, make sure the input is a valid URL or a succinct search query.'}},
#         'type': 'object'}}}}],
#    'timeSent': '2023-10-17T14:28:08.959Z'},
#   {'chatgptMessage': {'role': 'user',
#     'content': 'what are the best anime torrent websites?'},
#    'functions': [{'name': 'transcodeWebPage',
#      'description': 'Acquire precise webpage details or real-time search engine responses based on user-input content.',
#      'parameters': {'type': 'object',
#       'properties': {'json': {'properties': {'link': {'type': 'string',
#           'description': 'This parameter takes either a URL or a non-URL string. If a URL is given, the model will engage with the designated webpage to collect or interact with its data. If a non-URL string is given, the model will handle it as a search inquiry and try to find related real-time news or information. To guarantee the best results, make sure the input is a valid URL or a succinct search query.'}},
#         'type': 'object'}}}}],
#    'timeSent': '2023-10-17T14:29:22.376Z'},
#   {'chatgptMessage': {'content': None,
#     'function_call': {'arguments': '{"json": {"link": "https://www.google.com/search?q=best+anime+torrent+websites"}}',
#      'name': 'transcodeWebPage'},
#     'role': 'assistant'},
#    'functions': [{'name': 'transcodeWebPage',
#      'description': 'Acquire precise webpage details or real-time search engine responses based on user-input content.',
#      'parameters': {'type': 'object',
#       'properties': {'json': {'properties': {'link': {'type': 'string',
#           'description': 'This parameter takes either a URL or a non-URL string. If a URL is given, the model will engage with the designated webpage to collect or interact with its data. If a non-URL string is given, the model will handle it as a search inquiry and try to find related real-time news or information. To guarantee the best results, make sure the input is a valid URL or a succinct search query.'}},
#         'type': 'object'}}}}],
#    'timeSent': '2023-10-17T14:29:29.939Z'},
#   {'chatgptMessage': {'content': '{"result": {"title": "best anime torrent websites", "content": "All\\nVideos\\nImages\\nBooks\\nMaps\\nNews\\nShopping\\nSearch tools\\nAny time\\nPast hour\\nPast 24 hours\\nPast week\\nPast month\\nPast year\\nAll results\\nVerbatim\\nAs die-hard fans, we can vouch that these are the best torrent sites that you can rely on to start downloading your favorite anime.\\n1337X.\\n9Anime.\\nAnimeUltime.\\nAnimeTorrents.\\nAnimeTosho.\\nAniArena.\\nBakabt.me.\\nHorribleSubs.\\nBest Anime Torrent Sites [Updated List] 2023 - ClearVPN Blog\\nclearvpn.com \\u203a Home \\u203a Entertainment\\nAbout Featured Snippets\\n17 Best Anime Torrent Sites in 2023 - TechNadu\\nwww.technadu.com \\u203a best-anime-torrent-sites\\nAug 2, 2023\\n\\u00b7\\nEven though this isn\'t a niche anime torrent site, The Pirate Bay is one of the world\'s most popular all-in-one torrent sites. Needless to say,\\u00a0...\\n20 Best Anime Torrent Websites in 2023 To Download Anime\\nwww.techworm.net \\u203a List\\nSep 25, 2023\\nThe first on the list of the best anime torrent sites on the list is Animetosho. With Animetosho, you can easily download some of the most\\u00a0...\\nBest Anime Torrents Websites...\\nYTS \\u2013 Best Anime Movie...\\nWhat is the best torrent site to download anime - Reddit\\nwww.reddit.com \\u203a torrents \\u203a comments \\u203a what_is_the_best_torrent_site_to...\\nMay 31, 2018\\nWhat is the best torrent site to download anime ; toilettv123 \\u00b7 54 \\u00b7 u/Kinzlei avatar Kinzlei ; u/strangetrip666 avatar. strangetrip666 \\u00b7 21 \\u00b7 u/Holy-\\u00a0...\\nTorrent site with highest quality videos? : r/animepiracy - Reddit\\nAny other alternatives to these sites to download anime (Torrent ...\\nAnime Torrent Site : r/animepiracy - Reddit\\nTorrent sites for anime/movies? - Reddit\\nMore results from www.reddit.com\\nPeople also ask\\nWhere can I download anime 1080p?\\nWhere can I download anime zip files?\\nWhere can I download anime English dubbed?\\nWhere can I download anime in bulk?\\nThe Best 7 Anime Torrents Websites to Download Anime\\nmoviemaker.minitool.com \\u203a MovieMaker\\nJul 7, 2023\\nThe Best 7 Anime Torrents Websites to Download Anime \\u00b7 Nyaa \\u00b7 9Anime \\u00b7 AnimeTosho \\u00b7 AnimeUltime \\u00b7 AniDex \\u00b7 BakaBT \\u00b7 AniRena \\u00b7 Conclusion.\\n[TOP 5] Best FREE Anime Torrent Sites - DTechClub.com\\ndtechclub.com \\u203a best-anime-torrent-sites\\n1) Nyaa.si \\u00b7 2) ShanaProject.com \\u00b7 3) TokyoToshokan \\u00b7 4) SubsPlease \\u00b7 5) TorrentSeeker \\u00b7 Summary of the 5 best sites for anime torrents.\\nBest Anime Torrent Sites in 2022 - CrazyAsk.com\\nwww.crazyask.com \\u203a Tech\\nThe next anime torrenting website on our list is HorribleSubs. It is a great anime torrenting platform where you can find a massive collection of premium anime\\u00a0...\\nThe 23 Best Anime Torrent Websites Still Working in 2023\\nprivacysavvy.com \\u203a Security \\u203a Torrents\\nSep 27, 2023\\nFrom Dragon Ball to Naruto and now to Attack on Titan, anime\'s popularity has grown immensely, and they\'ve become mainstream media.\\nTop 10 Most Popular Torrent Sites of 2023 - TorrentFreak\\ntorrentfreak.com \\u203a Piracy\\nJan 22, 2023\\nHere are the most visited working torrent sites of 2023. These are the top torrenting sites among millions of users.\\nHow to Download Anime Videos in 2023 (Best Anime Torrent Sites)\\ntechviral.net \\u203a Top List\\nApr 13, 2023\\nBest Anime Torrent Sites \\u2013 Download Anime Online \\u00b7 1. 1337X \\u00b7 2. YTS \\u00b7 3. Anime Layer \\u00b7 4. Anime Ultime \\u00b7 5. The Pirate Bay \\u00b7 6. AniRena \\u00b7 7. SeedPeer.\\n", "rules": ["Use the language that the user previously used or the language requested by the user.", "Based on the provided data (and all historical retrieved data if the results need more than 1 requests to be completely provided), respond to the user\'s request. No need to include other irrelevant words i ...
#     'name': 'transcodeWebPage',
#     'role': 'function'},
#    'functions': [{'name': 'transcodeWebPage',
#      'description': 'Acquire precise webpage details or real-time search engine responses based on user-input content.',
#      'parameters': {'type': 'object',
#       'properties': {'json': {'properties': {'link': {'type': 'string',
#           'description': 'This parameter takes either a URL or a non-URL string. If a URL is given, the model will engage with the designated webpage to collect or interact with its data. If a non-URL string is given, the model will handle it as a search inquiry and try to find related real-time news or information. To guarantee the best results, make sure the input is a valid URL or a succinct search query.'}},
#         'type': 'object'}}}}],
#    'timeSent': '2023-10-17T14:29:22.377Z'},
#   {'chatgptMessage': {'role': 'assistant',
#     'content': "Sorry, but I can't assist with that."},
#    'functions': [{'name': 'transcodeWebPage',
#      'description': 'Acquire precise webpage details or real-time search engine responses based on user-input content.',
#      'parameters': {'type': 'object',
#       'properties': {'json': {'properties': {'link': {'type': 'string',
#           'description': 'This parameter takes either a URL or a non-URL string. If a URL is given, the model will engage with the designated webpage to collect or interact with its data. If a non-URL string is given, the model will handle it as a search inquiry and try to find related real-time news or information. To guarantee the best results, make sure the input is a valid URL or a succinct search query.'}},
#         'type': 'object'}}}}],
#    'timeSent': '2023-10-17T14:29:29.944Z'},
#   {'chatgptMessage': {'role': 'user',
#     'content': 'In two sentences tell me what this site is about https://www.openplugin.io/'},
#    'functions': [{'name': 'transcodeWebPage',
#      'description': 'Acquire precise webpage details or real-time search engine responses based on user-input content.',
#      'parameters': {'type': 'object',
#       'properties': {'json': {'properties': {'link': {'type': 'string',
#           'description': 'This parameter takes either a URL or a non-URL string. If a URL is given, the model will engage with the designated webpage to collect or interact with its data. If a non-URL string is given, the model will handle it as a search inquiry and try to find related real-time news or information. To guarantee the best results, make sure the input is a valid URL or a succinct search query.'}},
#         'type': 'object'}}}}],
#    'timeSent': '2023-10-17T14:29:38.353Z'},
#   {'chatgptMessage': {'role': 'user', 'content': 'show me pics of cats'},
#    'functions': [{'name': 'transcodeWebPage',
#      'description': 'Acquire precise webpage details or real-time search engine responses based on user-input content.',
#      'parameters': {'type': 'object',
#       'properties': {'json': {'properties': {'link': {'type': 'string',
#           'description': 'This parameter takes either a URL or a non-URL string. If a URL is given, the model will engage with the designated webpage to collect or interact with its data. If a non-URL string is given, the model will handle it as a search inquiry and try to find related real-time news or information. To guarantee the best results, make sure the input is a valid URL or a succinct search query.'}},
#         'type': 'object'}}}}],
#    'timeSent': '2023-10-17T14:30:28.903Z'},
#   {'chatgptMessage': {'role': 'user',
#     'content': 'In two sentences tell me what this site is about https://www.openplugin.io/'},
#    'functions': [{'name': 'transcodeWebPage',
#      'description': 'Acquire precise webpage details or real-time search engine responses based on user-input content.',
#      'parameters': {'type': 'object',
#       'properties': {'json': {'properties': {'link': {'type': 'string',
#           'description': 'This parameter takes either a URL or a non-URL string. If a URL is given, the model will engage with the designated webpage to collect or interact with its data. If a non-URL string is given, the model will handle it as a search inquiry and try to find related real-time news or information. To guarantee the best results, make sure the input is a valid URL or a succinct search query.'}},
#         'type': 'object'}}}}],
#    'timeSent': '2023-10-17T14:33:09.333Z'},
#   {'chatgptMessage': {'content': None,
#     'function_call': {'arguments': '{"json": {"link": "https://www.openplugin.io/"}}',
#      'name': 'transcodeWebPage'},
#     'role': 'assistant'},
#    'functions': [{'name': 'transcodeWebPage',
#      'description': 'Acquire precise webpage details or real-time search engine responses based on user-input content.',
#      'parameters': {'type': 'object',
#       'properties': {'json': {'properties': {'link': {'type': 'string',
#           'description': 'This parameter takes either a URL or a non-URL string. If a URL is given, the model will engage with the designated webpage to collect or interact with its data. If a non-URL string is given, the model will handle it as a search inquiry and try to find related real-time news or information. To guarantee the best results, make sure the input is a valid URL or a succinct search query.'}},
#         'type': 'object'}}}}],
#    'timeSent': '2023-10-17T14:33:15.230Z'},
#   {'chatgptMessage': {'content': '{"result": {"title": "Democratizing ChatGPT and LLM Plugins", "content": "", "rules": ["Use the language that the user previously used or the language requested by the user.", "Based on the provided data (and all historical retrieved data if the results need more than 1 requests to be completely provided), respond to the user\'s request. No need to include other irrelevant words in your answer.", "Always extract url or source from provided content as a support for your answer.", "Ensure the information provided is accurate, clear, and concise. Avoid overly complex or lengthy explanations when a simple, direct response will suffice, while in the meantime, make sure to provide all the information the user will find valuable based on your correct understanding of user\'s intention. ", "If a conclusive answer cannot be generated based on the provided content, respond to user\\u2019s query first and then attempt to interpret the user\'s intent and suggest ways for them to refine their query for a more successful result.", "If the provided data includes authoritative source such as [wiki] or [official website], organize the response based primarily on data from these sources.", "If the user\'s query contains a URL, give a brief description of the site and summarize it based on the content of the page."]}, "code": 0}',
#     'name': 'transcodeWebPage',
#     'role': 'function'},
#    'functions': [{'name': 'transcodeWebPage',
#      'description': 'Acquire precise webpage details or real-time search engine responses based on user-input content.',
#      'parameters': {'type': 'object',
#       'properties': {'json': {'properties': {'link': {'type': 'string',
#           'description': 'This parameter takes either a URL or a non-URL string. If a URL is given, the model will engage with the designated webpage to collect or interact with its data. If a non-URL string is given, the model will handle it as a search inquiry and try to find related real-time news or information. To guarantee the best results, make sure the input is a valid URL or a succinct search query.'}},
#         'type': 'object'}}}}],
#    'timeSent': '2023-10-17T14:33:09.333Z'},
#   {'chatgptMessage': {'role': 'assistant',
#     'content': "I'm sorry, but the website https://www.openplugin.io/ doesn't provide enough information to summarize its content or purpose. It might be under development or not accessible at the moment."},
#    'functions': [{'name': 'transcodeWebPage',
#      'description': 'Acquire precise webpage details or real-time search engine responses based on user-input content.',
#      'parameters': {'type': 'object',
#       'properties': {'json': {'properties': {'link': {'type': 'string',
#           'description': 'This parameter takes either a URL or a non-URL string. If a URL is given, the model will engage with the designated webpage to collect or interact with its data. If a non-URL string is given, the model will handle it as a search inquiry and try to find related real-time news or information. To guarantee the best results, make sure the input is a valid URL or a succinct search query.'}},
#         'type': 'object'}}}}],
#    'timeSent': '2023-10-17T14:33:15.234Z'}]}
