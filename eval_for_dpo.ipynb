# %%
# !pip install "transformers==4.34.0" "datasets==2.13.0" "peft==0.4.0" "accelerate==0.23.0" "bitsandbytes==0.41.1" "trl==0.4.7" "safetensors>=0.3.1" ipywidgets wandb --upgrade
# !python -c "import torch; assert torch.cuda.get_device_capability()[0] >= 8, 'Hardware not supported for Flash Attention'"
# !pip install ninja packaging
# !MAX_JOBS=1 pip install flash-attn --no-build-isolation
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: transformers==4.34.0 in /home/sosa.s/.local/lib/python3.10/site-packages (4.34.0)
# Requirement already satisfied: datasets==2.13.0 in /home/sosa.s/.local/lib/python3.10/site-packages (2.13.0)
# Requirement already satisfied: peft==0.4.0 in /home/sosa.s/.local/lib/python3.10/site-packages (0.4.0)
# Requirement already satisfied: accelerate==0.23.0 in /home/sosa.s/.local/lib/python3.10/site-packages (0.23.0)
# Requirement already satisfied: bitsandbytes==0.41.1 in /home/sosa.s/.local/lib/python3.10/site-packages (0.41.1)
# Requirement already satisfied: trl==0.4.7 in /home/sosa.s/.local/lib/python3.10/site-packages (0.4.7)
# Requirement already satisfied: safetensors>=0.3.1 in /home/sosa.s/.local/lib/python3.10/site-packages (0.4.0)
# Requirement already satisfied: ipywidgets in /home/sosa.s/.local/lib/python3.10/site-packages (8.1.1)
# Requirement already satisfied: wandb in /home/sosa.s/.local/lib/python3.10/site-packages (0.16.0)
# Requirement already satisfied: filelock in /apps/pytorch/2.0.1/lib/python3.10/site-packages (from transformers==4.34.0) (3.12.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /home/sosa.s/.local/lib/python3.10/site-packages (from transformers==4.34.0) (0.17.3)
# Requirement already satisfied: numpy>=1.17 in /apps/pytorch/2.0.1/lib/python3.10/site-packages (from transformers==4.34.0) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /apps/pytorch/2.0.1/lib/python3.10/site-packages (from transformers==4.34.0) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /apps/pytorch/2.0.1/lib/python3.10/site-packages (from transformers==4.34.0) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/sosa.s/.local/lib/python3.10/site-packages (from transformers==4.34.0) (2023.10.3)
# Requirement already satisfied: requests in /apps/pytorch/2.0.1/lib/python3.10/site-packages (from transformers==4.34.0) (2.29.0)
# Requirement already satisfied: tokenizers<0.15,>=0.14 in /home/sosa.s/.local/lib/python3.10/site-packages (from transformers==4.34.0) (0.14.1)
# Requirement already satisfied: tqdm>=4.27 in /apps/pytorch/2.0.1/lib/python3.10/site-packages (from transformers==4.34.0) (4.65.0)
# Requirement already satisfied: pyarrow>=8.0.0 in /home/sosa.s/.local/lib/python3.10/site-packages (from datasets==2.13.0) (14.0.0)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in /home/sosa.s/.local/lib/python3.10/site-packages (from datasets==2.13.0) (0.3.6)
# Requirement already satisfied: pandas in /home/sosa.s/.local/lib/python3.10/site-packages (from datasets==2.13.0) (2.1.3)
# Requirement already satisfied: xxhash in /home/sosa.s/.local/lib/python3.10/site-packages (from datasets==2.13.0) (3.4.1)
# Requirement already satisfied: multiprocess in /home/sosa.s/.local/lib/python3.10/site-packages (from datasets==2.13.0) (0.70.14)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /apps/pytorch/2.0.1/lib/python3.10/site-packages (from datasets==2.13.0) (2023.9.2)
# Requirement already satisfied: aiohttp in /apps/pytorch/2.0.1/lib/python3.10/site-packages (from datasets==2.13.0) (3.8.6)
# Requirement already satisfied: psutil in /apps/pytorch/2.0.1/lib/python3.10/site-packages (from peft==0.4.0) (5.9.5)
# Requirement already satisfied: torch>=1.13.0 in /apps/pytorch/2.0.1/lib/python3.10/site-packages (from peft==0.4.0) (2.0.1)
# Requirement already satisfied: comm>=0.1.3 in /apps/pytorch/2.0.1/lib/python3.10/site-packages (from ipywidgets) (0.1.3)
# Requirement already satisfied: ipython>=6.1.0 in /apps/pytorch/2.0.1/lib/python3.10/site-packages (from ipywidgets) (8.13.2)
# Requirement already satisfied: traitlets>=4.3.1 in /apps/pytorch/2.0.1/lib/python3.10/site-packages (from ipywidgets) (5.9.0)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in /home/sosa.s/.local/lib/python3.10/site-packages (from ipywidgets) (4.0.9)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in /home/sosa.s/.local/lib/python3.10/site-packages (from ipywidgets) (3.0.9)
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /apps/pytorch/2.0.1/lib/python3.10/site-packages (from wandb) (8.1.7)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in /home/sosa.s/.local/lib/python3.10/site-packages (from wandb) (3.1.40)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /home/sosa.s/.local/lib/python3.10/site-packages (from wandb) (1.34.0)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /home/sosa.s/.local/lib/python3.10/site-packages (from wandb) (0.4.0)
# Requirement already satisfied: setproctitle in /home/sosa.s/.local/lib/python3.10/site-packages (from wandb) (1.3.3)
# Requirement already satisfied: setuptools in /apps/pytorch/2.0.1/lib/python3.10/site-packages (from wandb) (67.7.2)
# Requirement already satisfied: appdirs>=1.4.3 in /home/sosa.s/.local/lib/python3.10/site-packages (from wandb) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /home/sosa.s/.local/lib/python3.10/site-packages (from wandb) (4.25.1)
# Requirement already satisfied: six>=1.4.0 in /apps/pytorch/2.0.1/lib/python3.10/site-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: attrs>=17.3.0 in /apps/pytorch/2.0.1/lib/python3.10/site-packages (from aiohttp->datasets==2.13.0) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /apps/pytorch/2.0.1/lib/python3.10/site-packages (from aiohttp->datasets==2.13.0) (3.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /apps/pytorch/2.0.1/lib/python3.10/site-packages (from aiohttp->datasets==2.13.0) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /apps/pytorch/2.0.1/lib/python3.10/site-packages (from aiohttp->datasets==2.13.0) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /apps/pytorch/2.0.1/lib/python3.10/site-packages (from aiohttp->datasets==2.13.0) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /apps/pytorch/2.0.1/lib/python3.10/site-packages (from aiohttp->datasets==2.13.0) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /apps/pytorch/2.0.1/lib/python3.10/site-packages (from aiohttp->datasets==2.13.0) (1.3.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/sosa.s/.local/lib/python3.10/site-packages (from GitPython!=3.1.29,>=1.0.0->wandb) (4.0.11)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /apps/pytorch/2.0.1/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.16.4->transformers==4.34.0) (4.5.0)
# Requirement already satisfied: backcall in /apps/pytorch/2.0.1/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: decorator in /apps/pytorch/2.0.1/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /apps/pytorch/2.0.1/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.18.2)
# Requirement already satisfied: matplotlib-inline in /apps/pytorch/2.0.1/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: pickleshare in /apps/pytorch/2.0.1/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /apps/pytorch/2.0.1/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.38)
# Requirement already satisfied: pygments>=2.4.0 in /apps/pytorch/2.0.1/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (2.15.1)
# Requirement already satisfied: stack-data in /apps/pytorch/2.0.1/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /apps/pytorch/2.0.1/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.8.0)
# Requirement already satisfied: idna<4,>=2.5 in /apps/pytorch/2.0.1/lib/python3.10/site-packages (from requests->transformers==4.34.0) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /apps/pytorch/2.0.1/lib/python3.10/site-packages (from requests->transformers==4.34.0) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /apps/pytorch/2.0.1/lib/python3.10/site-packages (from requests->transformers==4.34.0) (2023.7.22)
# Requirement already satisfied: sympy in /apps/pytorch/2.0.1/lib/python3.10/site-packages (from torch>=1.13.0->peft==0.4.0) (1.12)
# Requirement already satisfied: networkx in /apps/pytorch/2.0.1/lib/python3.10/site-packages (from torch>=1.13.0->peft==0.4.0) (3.1)
# Requirement already satisfied: jinja2 in /apps/pytorch/2.0.1/lib/python3.10/site-packages (from torch>=1.13.0->peft==0.4.0) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /apps/pytorch/2.0.1/lib/python3.10/site-packages (from pandas->datasets==2.13.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /apps/pytorch/2.0.1/lib/python3.10/site-packages (from pandas->datasets==2.13.0) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /home/sosa.s/.local/lib/python3.10/site-packages (from pandas->datasets==2.13.0) (2023.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/sosa.s/.local/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb) (5.0.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /apps/pytorch/2.0.1/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /apps/pytorch/2.0.1/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /apps/pytorch/2.0.1/lib/python3.10/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets) (0.2.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /apps/pytorch/2.0.1/lib/python3.10/site-packages (from jinja2->torch>=1.13.0->peft==0.4.0) (2.1.2)
# Requirement already satisfied: executing>=1.2.0 in /apps/pytorch/2.0.1/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /apps/pytorch/2.0.1/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: pure-eval in /apps/pytorch/2.0.1/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: mpmath>=0.19 in /apps/pytorch/2.0.1/lib/python3.10/site-packages (from sympy->torch>=1.13.0->peft==0.4.0) (1.3.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ninja in /home/sosa.s/.local/lib/python3.10/site-packages (1.11.1.1)
# Requirement already satisfied: packaging in /apps/pytorch/2.0.1/lib/python3.10/site-packages (23.1)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: flash-attn in /home/sosa.s/.local/lib/python3.10/site-packages (2.3.3)
# Requirement already satisfied: torch in /apps/pytorch/2.0.1/lib/python3.10/site-packages (from flash-attn) (2.0.1)
# Requirement already satisfied: einops in /home/sosa.s/.local/lib/python3.10/site-packages (from flash-attn) (0.7.0)
# Requirement already satisfied: packaging in /apps/pytorch/2.0.1/lib/python3.10/site-packages (from flash-attn) (23.1)
# Requirement already satisfied: ninja in /home/sosa.s/.local/lib/python3.10/site-packages (from flash-attn) (1.11.1.1)
# Requirement already satisfied: filelock in /apps/pytorch/2.0.1/lib/python3.10/site-packages (from torch->flash-attn) (3.12.0)
# Requirement already satisfied: typing-extensions in /apps/pytorch/2.0.1/lib/python3.10/site-packages (from torch->flash-attn) (4.5.0)
# Requirement already satisfied: sympy in /apps/pytorch/2.0.1/lib/python3.10/site-packages (from torch->flash-attn) (1.12)
# Requirement already satisfied: networkx in /apps/pytorch/2.0.1/lib/python3.10/site-packages (from torch->flash-attn) (3.1)
# Requirement already satisfied: jinja2 in /apps/pytorch/2.0.1/lib/python3.10/site-packages (from torch->flash-attn) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /apps/pytorch/2.0.1/lib/python3.10/site-packages (from jinja2->torch->flash-attn) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /apps/pytorch/2.0.1/lib/python3.10/site-packages (from sympy->torch->flash-attn) (1.3.0)

# %%
# add parent directory to path
import sys
import os

project_dir = os.getcwd()
parent_dir = os.path.dirname(project_dir)
sys.path.insert(0, parent_dir)

# %%
# configs
from huggingface_hub import notebook_login
# import wandb

model_id = "meta-llama/Llama-2-7b-chat-hf"
output_dir = "llama-7-chat-instruction-int4-fc-pipeline"
hub_model_id = f"SebastianS/{output_dir}"
# wandb.init(project="function_calling", id=output_dir, entity="sebastiansosa")
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# get data and convert to Datasets format
import pandas as pd
from datasets import Dataset, DatasetDict
from gaitor_function_calling.data.data_utils import DataAbstractor
from gaitor_function_calling.data.prompting_utils import INSTRUCTION

data_abstractor = DataAbstractor("production_data-without_summary-only_fc.json", "dpo_eval")

train_df = pd.DataFrame(data_abstractor.train_data)
test_df = pd.DataFrame(data_abstractor.test_data)

train_dataset = Dataset.from_pandas(train_df)
test_dataset = Dataset.from_pandas(test_df)

dataset_dict = DatasetDict({
    'train': train_dataset,
    'test': test_dataset
})

dataset_dict
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text'],
#         num_rows: 425
#     })
#     test: Dataset({
#         features: ['text'],
#         num_rows: 425
#     })
# })

# %%
# setup metrics and evaluation
import json
from transformers import EvalPrediction
from gaitor_function_calling.evaluation.evaluation_utils import FunctionCallingMetric, compute_perplexity, get_logits_and_labels
from gaitor_function_calling.data.prompting_utils import INSTRUCTION, json_arguments_from_prompt
import numpy as np

fc_metric = FunctionCallingMetric()
def config_compute_metrics(tokenizer):
    def compute_metrics(pred: EvalPrediction):
        # pred.predictions are a batch of logits
        # pred.label_ids are a batch of tokens
        token_ids = np.argmax(pred.predictions, axis=-1)
        predictions = tokenizer.batch_decode(token_ids, skip_special_tokens=False)
        labels = tokenizer.batch_decode(pred.label_ids, skip_special_tokens=False)
        
        
    
        # Now use your metric class
        fc_result = fc_metric.run(predictions, labels)  # Implement this method in your class
    
        return {
            "fc_combine": fc_result
        }
    return compute_metrics

def custom_evaluation(eval_dataset, model, tokenizer, save_prompts_path=False):
    print("Starting custom evaluation.")
    # model.eval()  # Set the model to evaluation mode
    results = {}

    fc_results = []

    if save_prompts_path:
        try:
            with open(save_prompts_path, "r") as f:
                dpo_data = json.load(f)
        except:
            dpo_data = []


    for idx, example in enumerate(eval_dataset):
        print(f"Example {idx}: ", end="")
        post_message = ""
        
        # Custom Function Calling metric
        fc_message = ""
        try:
            print("in try block")
            generated_arguments, expected_arguments, prompts = json_arguments_from_prompt(
                example["text"],
                model,
                tokenizer,
                INSTRUCTION
            )
            fc_result = fc_metric.run(generated_arguments, expected_arguments)
            # add prompts to dpo_data.json
            dpo_data.append({
                "fc_result": fc_result,
                **prompts
            })
            fc_results.append(fc_result)

            if save_prompts_path:
                with open(save_prompts_path, "w") as f:
                    json.dump(dpo_data, f)
        except Exception as e:
            post_message += f"Error function calling: {e}\n"
            fc_results.append(0)

        example_metric = {"fc_combine": fc_results[-1]}
        print(example_metric)
        if post_message:
            print(post_message)
        
    results["fc_combine"] =  sum(fc_results) / len(fc_results)

    return results

# %%
from transformers import AutoTokenizer
from peft import AutoPeftModelForCausalLM
import torch

# load base LLM model and tokenizer
model = AutoPeftModelForCausalLM.from_pretrained(
    hub_model_id,
    low_cpu_mem_usage=True,
    torch_dtype=torch.float16,
    load_in_4bit=True,
)
tokenizer = AutoTokenizer.from_pretrained(hub_model_id)
# Out:
# Downloading adapter_config.json:   0%|          | 0.00/451 [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading adapter_model.bin:   0%|          | 0.00/134M [00:00<?, ?B/s]
# Downloading tokenizer_config.json:   0%|          | 0.00/1.75k [00:00<?, ?B/s]
# Downloading tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# Downloading tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# Downloading added_tokens.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/95.0 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
dataset_dict["test"]
# Out:
# Dataset({
#     features: ['text'],
#     num_rows: 425
# })

# %%
eval_result = custom_evaluation(dataset_dict["test"], model, tokenizer, "data/prompts_data.json")
eval_result
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Starting custom evaluation.
# Example 0: in try block
# pre output generate
# /home/sosa.s/.local/lib/python3.10/site-packages/bitsandbytes/nn/modules.py:224: UserWarning: Input type into Linear4bit is torch.float16, but bnb_4bit_compute_type=torch.float32 (default). This will lead to slow inference or training speed.
#   warnings.warn(f'Input type into Linear4bit is torch.float16, but bnb_4bit_compute_type=torch.float32 (default). This will lead to slow inference or training speed.')
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# post output generate
# {'fc_combine': 0.5176492598321702}
# Example 1: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.53515545129776}
# Example 2: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: Expecting ',' delimiter: line 1 column 79 (char 78)
#
# Example 3: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6483641465504965}
# Example 4: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6554457545280457}
# Example 5: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6318585077921549}
# Example 6: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5127570877472559}
# Example 7: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6112533211708069}
# Example 8: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: division by zero
#
# Example 9: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.7312659442424774}
# Example 10: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5707712705646243}
# Example 11: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: max() arg is an empty sequence
#
# Example 12: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: division by zero
#
# Example 13: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.7657981912295023}
# Example 14: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: Expecting ',' delimiter: line 1 column 1296 (char 1295)
#
# Example 15: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5593437552452087}
# Example 16: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: 'NoneType' object has no attribute 'group'
#
# Example 17: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: max() arg is an empty sequence
#
# Example 18: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: max() arg is an empty sequence
#
# Example 19: in try block
# pre output generate
# post output generate
# {'fc_combine': 1.0}
# Example 20: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.816330095132192}
# Example 21: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6818191309769949}
# Example 22: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.4821676214536031}
# Example 23: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6902688145637512}
# Example 24: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: Expecting ',' delimiter: line 1 column 136 (char 135)
#
# Example 25: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6362191379070282}
# Example 26: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.585639476776123}
# Example 27: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6380175782574548}
# Example 28: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.7638051450252533}
# Example 29: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6230765283107758}
# Example 30: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: The size of tensor a (1583) must match the size of tensor b (512) at non-singleton dimension 1
#
# Example 31: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6080104768276214}
# Example 32: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.9310410420099894}
# Example 33: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: 'NoneType' object has no attribute 'group'
#
# Example 34: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: division by zero
#
# Example 35: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6753878990809122}
# Example 36: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.7707541882991791}
# Example 37: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6061446567376455}
# Example 38: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.7235134641329447}
# Example 39: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6522359053293864}
# Example 40: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: division by zero
#
# Example 41: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6677045822143555}
# Example 42: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.8603055874506632}
# Example 43: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6047264456748962}
# Example 44: in try block
# pre output generate
# post output generate
# {'fc_combine': 1.0}
# Example 45: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.7502716508778658}
# Example 46: in try block
# pre output generate
# post output generate
# {'fc_combine': 1.0}
# Example 47: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5694561153650284}
# Example 48: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: division by zero
#
# Example 49: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6620756089687347}
# Example 50: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: 'NoneType' object has no attribute 'group'
#
# Example 51: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: division by zero
#
# Example 52: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: max() arg is an empty sequence
#
# Example 53: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6115091741085052}
# Example 54: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.9600248098373413}
# Example 55: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: Expecting ',' delimiter: line 1 column 47 (char 46)
#
# Example 56: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6377807060877482}
# Example 57: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: max() arg is an empty sequence
#
# Example 58: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5385332746165139}
# Example 59: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.9685141205787658}
# Example 60: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5151548981666565}
# Example 61: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6766713460286459}
# Example 62: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.56988804936409}
# Example 63: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6894567012786865}
# Example 64: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6027608240644137}
# Example 65: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6658402582009634}
# Example 66: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.8809958299001058}
# Example 67: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.9313096602757772}
# Example 68: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: Expecting ',' delimiter: line 1 column 194 (char 193)
#
# Example 69: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6310560703277588}
# Example 70: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5376457626169379}
# Example 71: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: division by zero
#
# Example 72: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6347605032580239}
# Example 73: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6114800969759623}
# Example 74: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: division by zero
#
# Example 75: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: Expecting ',' delimiter: line 1 column 62 (char 61)
#
# Example 76: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5697932640711466}
# Example 77: in try block
# pre output generate
# post output generate
# {'fc_combine': 1.0}
# Example 78: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: max() arg is an empty sequence
#
# Example 79: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.9041437307993571}
# Example 80: in try block
# pre output generate
# post output generate
# {'fc_combine': 1.0}
# Example 81: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6223531862099966}
# Example 82: in try block
# pre output generate
# post output generate
# {'fc_combine': 1.0}
# Example 83: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6063278052541945}
# Example 84: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5980351368586222}
# Example 85: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5621915817260742}
# Example 86: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.7112562239170075}
# Example 87: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6483641465504965}
# Example 88: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.983277440071106}
# Example 89: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: max() arg is an empty sequence
#
# Example 90: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.7402762337164446}
# Example 91: in try block
# pre output generate
# post output generate
# {'fc_combine': 1.0}
# Example 92: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6280866662661234}
# Example 93: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6930208802223206}
# Example 94: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: division by zero
#
# Example 95: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: 'NoneType' object has no attribute 'group'
#
# Example 96: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.7979458815911237}
# Example 97: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: 'NoneType' object has no attribute 'group'
#
# Example 98: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: Expecting ',' delimiter: line 1 column 176 (char 175)
#
# Example 99: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.7007225394248963}
# Example 100: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.817992627620697}
# Example 101: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.7739737629890442}
# Example 102: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6318585077921549}
# Example 103: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6075270076592764}
# Example 104: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5616549253463745}
# Example 105: in try block
# pre output generate
# post output generate
# {'fc_combine': 1.0}
# Example 106: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: Expecting ',' delimiter: line 1 column 60 (char 59)
#
# Example 107: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: division by zero
#
# Example 108: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: division by zero
#
# Example 109: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.764381468296051}
# Example 110: in try block
# pre output generate
# post output generate
# {'fc_combine': 1.0}
# Example 111: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5131586449486869}
# Example 112: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.890511417388916}
# Example 113: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6245853304862976}
# Example 114: in try block
# pre output generate
# post output generate
# {'fc_combine': 1.0}
# Example 115: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6916954517364502}
# Example 116: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: 'NoneType' object has no attribute 'group'
#
# Example 117: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: 'NoneType' object has no attribute 'group'
#
# Example 118: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5826217035452524}
# Example 119: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: division by zero
#
# Example 120: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: division by zero
#
# Example 121: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6067468325297037}
# Example 122: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5729894254888807}
# Example 123: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.8314324716726939}
# Example 124: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5422987730966674}
# Example 125: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.7692476511001587}
# Example 126: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.4908529321352641}
# Example 127: in try block
# pre output generate
# post output generate
# {'fc_combine': 1.0}
# Example 128: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.9713150858879089}
# Example 129: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: 'NoneType' object has no attribute 'group'
#
# Example 130: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6585550308227539}
# Example 131: in try block
# pre output generate
# post output generate
# {'fc_combine': 1.0}
# Example 132: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.43979616676058086}
# Example 133: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.7630297144254049}
# Example 134: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6291561782360077}
# Example 135: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.43585582574208576}
# Example 136: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6169528961181641}
# Example 137: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: Expecting ',' delimiter: line 1 column 69 (char 68)
#
# Example 138: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: max() arg is an empty sequence
#
# Example 139: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: Expecting ',' delimiter: line 1 column 48 (char 47)
#
# Example 140: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.3804153310401099}
# Example 141: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: Expecting ',' delimiter: line 1 column 85 (char 84)
#
# Example 142: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.4994591474533081}
# Example 143: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: division by zero
#
# Example 144: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.8221879303455353}
# Example 145: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.43585582574208576}
# Example 146: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5910424987475077}
# Example 147: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: max() arg is an empty sequence
#
# Example 148: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: 'NoneType' object has no attribute 'group'
#
# Example 149: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6029382646083832}
# Example 150: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: max() arg is an empty sequence
#
# Example 151: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.7693859755992889}
# Example 152: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: division by zero
#
# Example 153: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: 'NoneType' object has no attribute 'group'
#
# Example 154: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: max() arg is an empty sequence
#
# Example 155: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: Expecting ',' delimiter: line 1 column 91 (char 90)
#
# Example 156: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.819763203461965}
# Example 157: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: Expecting ',' delimiter: line 1 column 58 (char 57)
#
# Example 158: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.7629879911740621}
# Example 159: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6580494741598765}
# Example 160: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: division by zero
#
# Example 161: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.7116407950719198}
# Example 162: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6343837738037109}
# Example 163: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6951582233111063}
# Example 164: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: division by zero
#
# Example 165: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.7392086803913116}
# Example 166: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5630700588226318}
# Example 167: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.7958631714185079}
# Example 168: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5800563139574868}
# Example 169: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: 'NoneType' object has no attribute 'group'
#
# Example 170: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6289665202299753}
# Example 171: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.7300372890063694}
# Example 172: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.910579936844962}
# Example 173: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.9305794494492667}
# Example 174: in try block
# pre output generate
# post output generate
# {'fc_combine': 1.0}
# Example 175: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.62130934993426}
# Example 176: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5791053672631582}
# Example 177: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.913356880346934}
# Example 178: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.4821676214536031}
# Example 179: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6061446567376455}
# Example 180: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.7461297114690145}
# Example 181: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6251008927822113}
# Example 182: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: division by zero
#
# Example 183: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: division by zero
#
# Example 184: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.8455878297487894}
# Example 185: in try block
# pre output generate
# post output generate
# {'fc_combine': 1.0}
# Example 186: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.7031758626302084}
# Example 187: in try block
# pre output generate
# post output generate
# {'fc_combine': 1.0}
# Example 188: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6275560557842255}
# Example 189: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.7542563577493032}
# Example 190: in try block
# pre output generate
# post output generate
# {'fc_combine': 1.0}
# Example 191: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.7737549344698588}
# Example 192: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: Expecting ',' delimiter: line 1 column 102 (char 101)
#
# Example 193: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5901015301545461}
# Example 194: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6540620241846357}
# Example 195: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5346193969249725}
# Example 196: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5761114557584127}
# Example 197: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.596008171637853}
# Example 198: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6662368973096212}
# Example 199: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6569991409778595}
# Example 200: in try block
# pre output generate
# post output generate
# {'fc_combine': 1.0}
# Example 201: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: division by zero
#
# Example 202: in try block
# pre output generate
# post output generate
# {'fc_combine': 1.0}
# Example 203: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5506659199794134}
# Example 204: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6136282299246106}
# Example 205: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6746390461921692}
# Example 206: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5716983444160886}
# Example 207: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.820097953081131}
# Example 208: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: division by zero
#
# Example 209: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.7925436581884112}
# Example 210: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6551321595907211}
# Example 211: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6969947069883347}
# Example 212: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5934945543607076}
# Example 213: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.9211798071861267}
# Example 214: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5756526231765747}
# Example 215: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.4410303036371867}
# Example 216: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5272425711154938}
# Example 217: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5135621527830759}
# Example 218: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6677045822143555}
# Example 219: in try block
# pre output generate
# post output generate
# {'fc_combine': 1.0}
# Example 220: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5776730411582522}
# Example 221: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.604833165804545}
# Example 222: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6660803556442261}
# Example 223: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.43786103857888115}
# Example 224: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6067468325297037}
# Example 225: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.658972422281901}
# Example 226: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.7629879911740621}
# Example 227: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: division by zero
#
# Example 228: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6080556469304221}
# Example 229: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.7134973208109537}
# Example 230: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5424390524625778}
# Example 231: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: division by zero
#
# Example 232: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.7856737573941549}
# Example 233: in try block
# pre output generate
# post output generate
# {'fc_combine': 1.0}
# Example 234: in try block
# pre output generate
# post output generate
# {'fc_combine': 1.0}
# Example 235: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.8434107184410096}
# Example 236: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.4776797294616699}
# Example 237: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6359793543815613}
# Example 238: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.9550015568733216}
# Example 239: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: division by zero
#
# Example 240: in try block
# pre output generate
# post output generate
# {'fc_combine': 1.0}
# Example 241: in try block
# pre output generate
# post output generate
# {'fc_combine': 1.0}
# Example 242: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5708603978157043}
# Example 243: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6185612181822459}
# Example 244: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.705149511496226}
# Example 245: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: division by zero
#
# Example 246: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: Expecting ',' delimiter: line 1 column 130 (char 129)
#
# Example 247: in try block
# pre output generate
# post output generate
# {'fc_combine': 1.0}
# Example 248: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6750534325838089}
# Example 249: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.589639683564504}
# Example 250: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.4845901330312093}
# Example 251: in try block
# pre output generate
# post output generate
# {'fc_combine': 1.0}
# Example 252: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6543241838614146}
# Example 253: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: 'NoneType' object has no attribute 'group'
#
# Example 254: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.8860988020896912}
# Example 255: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5650840600331625}
# Example 256: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.7743603984514872}
# Example 257: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.7235134641329447}
# Example 258: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5214550137519837}
# Example 259: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5593437552452087}
# Example 260: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6167757113774618}
# Example 261: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6031785011291504}
# Example 262: in try block
# pre output generate
# post output generate
# {'fc_combine': 1.0}
# Example 263: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.9513373374938965}
# Example 264: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6246332625548044}
# Example 265: in try block
# pre output generate
# post output generate
# {'fc_combine': 1.0}
# Example 266: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5467610061168671}
# Example 267: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.8824995358784994}
# Example 268: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: division by zero
#
# Example 269: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.9111630320549011}
# Example 270: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6551024675369262}
# Example 271: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6548628608385721}
# Example 272: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5593437552452087}
# Example 273: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: 'NoneType' object has no attribute 'group'
#
# Example 274: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5739191222403731}
# Example 275: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6094317649091993}
# Example 276: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.4908529321352641}
# Example 277: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: max() arg is an empty sequence
#
# Example 278: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.9456062912940979}
# Example 279: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: 'NoneType' object has no attribute 'group'
#
# Example 280: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5504323244094849}
# Example 281: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6546301345030466}
# Example 282: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.7079603672027588}
# Example 283: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: max() arg is an empty sequence
#
# Example 284: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6867333650588989}
# Example 285: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: Expecting ',' delimiter: line 1 column 211 (char 210)
#
# Example 286: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5963744103908539}
# Example 287: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: division by zero
#
# Example 288: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6454675942659378}
# Example 289: in try block
# pre output generate
# post output generate
# {'fc_combine': 1.0}
# Example 290: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: Expecting ',' delimiter: line 1 column 104 (char 103)
#
# Example 291: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.4830694771729983}
# Example 292: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: Expecting ',' delimiter: line 1 column 102 (char 101)
#
# Example 293: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: division by zero
#
# Example 294: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.7486433188120524}
# Example 295: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.8567003846168518}
# Example 296: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.4821676214536031}
# Example 297: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6475244561831156}
# Example 298: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.7691893180211385}
# Example 299: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6359793543815613}
# Example 300: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5508524179458618}
# Example 301: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6528704861799876}
# Example 302: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: division by zero
#
# Example 303: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.4477150837580363}
# Example 304: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.604873788356781}
# Example 305: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: max() arg is an empty sequence
#
# Example 306: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: 'NoneType' object has no attribute 'group'
#
# Example 307: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5685805355509123}
# Example 308: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6683754324913025}
# Example 309: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.48851531744003296}
# Example 310: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.53515545129776}
# Example 311: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5845479269822439}
# Example 312: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: 'NoneType' object has no attribute 'group'
#
# Example 313: in try block
# pre output generate
# post output generate
# {'fc_combine': 1.0}
# Example 314: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: Expecting ',' delimiter: line 1 column 82 (char 81)
#
# Example 315: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.7008606592814127}
# Example 316: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.8861503203709921}
# Example 317: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: 'NoneType' object has no attribute 'group'
#
# Example 318: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.9253066182136536}
# Example 319: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: division by zero
#
# Example 320: in try block
# pre output generate
# post output generate
# {'fc_combine': 1.0}
# Example 321: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5504323244094849}
# Example 322: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.8717698256174723}
# Example 323: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6115091741085052}
# Example 324: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.9713150858879089}
# Example 325: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6873359878857931}
# Example 326: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5553760886192322}
# Example 327: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.8316069756235395}
# Example 328: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: 'NoneType' object has no attribute 'group'
#
# Example 329: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.7371547818183899}
# Example 330: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.8816937437424293}
# Example 331: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5101343929767609}
# Example 332: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.7525690466165542}
# Example 333: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5980351368586222}
# Example 334: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5867802600065867}
# Example 335: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.8578177491823832}
# Example 336: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5291206041971842}
# Example 337: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: division by zero
#
# Example 338: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: 'NoneType' object has no attribute 'group'
#
# Example 339: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.9397250652313233}
# Example 340: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.7416829069455465}
# Example 341: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.9075347781181335}
# Example 342: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.7534297466278076}
# Example 343: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.8809958299001058}
# Example 344: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: division by zero
#
# Example 345: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6818191309769949}
# Example 346: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.7954368889331818}
# Example 347: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6092222929000854}
# Example 348: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5608929445346197}
# Example 349: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5742028405268987}
# Example 350: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6604895840088526}
# Example 351: in try block
# pre output generate
# post output generate
# {'fc_combine': 1.0}
# Example 352: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5757648944854736}
# Example 353: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6111702024936676}
# Example 354: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5233594179153442}
# Example 355: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6689765353997549}
# Example 356: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5349236854485103}
# Example 357: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.7111269116401673}
# Example 358: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: 'NoneType' object has no attribute 'group'
#
# Example 359: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: Expecting ',' delimiter: line 1 column 494 (char 493)
#
# Example 360: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.7463157176971436}
# Example 361: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.40590447187423706}
# Example 362: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5783493944576809}
# Example 363: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5614129155874252}
# Example 364: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.8728716611862183}
# Example 365: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6414986153443655}
# Example 366: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.9256837368011475}
# Example 367: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: 'NoneType' object has no attribute 'group'
#
# Example 368: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.7263033807277679}
# Example 369: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.4401918172836304}
# Example 370: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.4821676214536031}
# Example 371: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.7684625278819691}
# Example 372: in try block
# pre output generate
# post output generate
# {'fc_combine': 1.0}
# Example 373: in try block
# pre output generate
# post output generate
# {'fc_combine': 1.0}
# Example 374: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: 'NoneType' object has no attribute 'group'
#
# Example 375: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.72689621647199}
# Example 376: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6357900202274323}
# Example 377: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5860607226689657}
# Example 378: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5372552782297134}
# Example 379: in try block
# pre output generate
# post output generate
# {'fc_combine': 1.0}
# Example 380: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.7912378311157227}
# Example 381: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.739883017539978}
# Example 382: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.7133608857790629}
# Example 383: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5640744268894196}
# Example 384: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.9650970697402954}
# Example 385: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5320293945925576}
# Example 386: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6379285951455435}
# Example 387: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.8394688765207926}
# Example 388: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.7322157621383667}
# Example 389: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.8716466625531515}
# Example 390: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6111672023932139}
# Example 391: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.898567157132285}
# Example 392: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: division by zero
#
# Example 393: in try block
# pre output generate
# post output generate
# {'fc_combine': 1.0}
# Example 394: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5991154942247603}
# Example 395: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6095770398775736}
# Example 396: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.7215237736701965}
# Example 397: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: Extra data: line 1 column 22 (char 21)
#
# Example 398: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.7526101072629293}
# Example 399: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.8849357604980469}
# Example 400: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.9089125593503317}
# Example 401: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.7116016507148742}
# Example 402: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: Expecting ',' delimiter: line 1 column 64 (char 63)
#
# Example 403: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5363204876581827}
# Example 404: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6805901765823364}
# Example 405: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6593149056037267}
# Example 406: in try block
# pre output generate
# post output generate
# {'fc_combine': 1.0}
# Example 407: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: 'NoneType' object has no attribute 'group'
#
# Example 408: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6063117161393166}
# Example 409: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: division by zero
#
# Example 410: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: division by zero
#
# Example 411: in try block
# pre output generate
# post output generate
# {'fc_combine': 1.0}
# Example 412: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.8006425301233927}
# Example 413: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: division by zero
#
# Example 414: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5254837155342102}
# Example 415: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6698886156082153}
# Example 416: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5500293791294097}
# Example 417: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6126746336619059}
# Example 418: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5650840600331625}
# Example 419: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6499446233113607}
# Example 420: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: 'NoneType' object has no attribute 'group'
#
# Example 421: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: division by zero
#
# Example 422: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.6712156704493931}
# Example 423: in try block
# pre output generate
# post output generate
# {'fc_combine': 0}
# Error function calling: 'NoneType' object has no attribute 'group'
#
# Example 424: in try block
# pre output generate
# post output generate
# {'fc_combine': 0.5755622784296671}
# {'fc_combine': 0.5420713784818879}
